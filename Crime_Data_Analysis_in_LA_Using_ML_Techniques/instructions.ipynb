# %% [markdown]
# # Crime Data Analysis in LA Using ML Techniques
#
# ## Project Structure
#
# Crime_Data_Analysis_in_LA_Using_ML_Techniques/
# │
# ├── data/
# │ └── raw_data/
# │ └── Crime_Data_from_2020.csv
# │
# ├── notebooks/
# │ └── experiments.ipynb
# │
# ├── pickle_files/
# │ └── .gitkeep
# │
# ├── scripts/
# │ ├── data_loader.py
# │ ├── data_cleaning.py
# │ ├── data_preprocessing.py
# │ ├── eda_analysis.py
# │ ├── ml_analysis.py
# │ ├── crime_dashboard.py
# │ └── propability_dashboard.py
# │
# ├── tests/
# │
# ├── img/
# │
# ├── .gitignore
# ├── .gitattributes
# ├── requirements.txt
# └── README.md
#
#
# ## Setup Instructions
#
# 1. **Clone the repository:**
#    ```bash
#    git clone <repository-url>
#    cd Crime_Data_Analysis_in_LA_Using_ML_Techniques
#
# python -m venv venv
# source venv/bin/activate   # On Windows use `venv\Scripts\activate`
#
#
# pip install -r requirements.txt
#
# Download the dataset:
# Place your dataset (Crime_Data_from_2020.csv) in the data/raw_data/ directory.
#
# python scripts/data_loader.py
# python scripts/data_cleaning.py
# python scripts/data_preprocessing.py
# python scripts/eda_analysis.py
# python scripts/ml_analysis.py
# python scripts/crime_dashboard.py
# python scripts/propability_dashboard.py
#
#
# Additional Information
# Notebooks:
#
# You can find additional experiments and analysis in the Jupyter notebook located in the notebooks/ directory.
# Tests:
#
# The tests/ directory contains tests to validate the functionality of your scripts.
# Images:
#
# The img/ directory can be used to store any images or figures generated during the analysis.
#
# For any questions or issues, please refer to the documentation or contact the project maintainers.
